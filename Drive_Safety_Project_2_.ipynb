jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/590.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/591.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/592.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/593.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/595.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/596.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/597.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/598.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/599.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/6.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/600.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/601.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/602.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/603.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/604.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/605.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/606.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/607.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/608.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/609.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/610.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/611.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/612.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/613.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/614.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/615.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/616.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/617.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/618.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/619.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/620.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/621.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/622.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/623.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/624.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/625.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/626.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/627.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/628.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/629.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/630.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/631.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/632.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/633.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/634.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/635.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/636.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/637.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/638.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/639.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/640.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/641.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/642.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/643.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/644.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/645.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/646.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/647.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/648.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/649.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/650.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/651.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/652.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/653.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/654.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/655.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/656.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/657.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/658.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/659.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/660.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/661.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/662.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/663.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/664.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/665.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/666.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/667.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/668.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/669.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/670.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/671.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/672.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/673.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/675.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/677.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/678.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/679.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/680.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/681.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/682.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/683.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/684.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/685.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/686.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/687.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/688.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/689.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/690.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/692.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/693.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/694.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/695.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/699.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/7.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/700.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/701.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/702.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/703.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/704.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/705.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/706.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/707.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/708.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/709.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/710.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/711.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/712.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/713.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/714.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/715.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/716.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/717.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/718.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/719.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/720.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/722.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/723.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/724.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/725.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/726.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/727.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/728.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/729.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/730.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/733.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/734.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/735.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/736.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/739.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/740.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/741.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/742.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/743.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/744.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/746.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/747.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/748.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/749.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/750.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/751.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/752.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/753.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/754.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/755.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/756.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/757.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/759.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/760.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/761.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/762.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/763.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/764.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/765.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/769.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/770.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/771.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/772.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/773.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/774.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/775.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/776.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/777.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/778.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/779.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/780.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/781.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/785.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/786.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/787.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/788.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/789.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/790.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/791.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/793.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/794.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/796.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/798.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/799.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/8.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/800.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/801.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/802.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/803.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/804.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/805.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/806.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/808.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/809.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/810.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/811.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/812.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/813.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/814.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/816.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/817.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/818.jpg
#   inflating: /content/drowsiness_dataset/Dataset/Val/Yawn/9.jpg

# %%
train_path="/content/drowsiness_dataset/Dataset/Train"
val_path="/content/drowsiness_dataset/Dataset/Val"
test_path="/content/drowsiness_dataset/Dataset/Test"

# %%
print(os.listdir("/content/drowsiness_dataset/Dataset"))
# Out:
# ['Train', 'Test', 'Val']

# %%
print("Train:", os.listdir(train_path))
print("___")
print("Validation:", os.listdir(val_path))
print("___")
print("Test:", os.listdir(test_path))
# Out:
# Train: ['Yawn', 'Open_Eyes', 'No_yawn', 'Closed_Eyes']
# ___
# Validation: ['Yawn', 'Open_Eyes', 'No_yawn', 'Closed_Eyes']
# ___
# Test: ['Yawn', 'Open_Eyes', 'No_yawn', 'Closed_Eyes']

# %%
IMG_SIZE = (64, 64)
BATCH_SIZE = 32

# %%
eye_classes = ["Closed_Eyes", "Open_Eyes"]
mouth_classes = ["No_yawn", "Yawn"]

print("Eye classes:", eye_classes)
print("Mouth classes:", mouth_classes)
# Out:
# Eye classes: ['Closed_Eyes', 'Open_Eyes']
# Mouth classes: ['No_yawn', 'Yawn']

# %%
eye_train_ds = tf.keras.utils.image_dataset_from_directory(
    train_path,
    labels="inferred",
    label_mode="binary",
    class_names=["Closed_Eyes", "Open_Eyes"],
    color_mode="grayscale",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True
)
# Out:
# Found 4233 files belonging to 2 classes.

# %%
print(eye_train_ds.class_names)
# Out:
# ['Closed_Eyes', 'Open_Eyes']

# %%
eye_val_ds = tf.keras.utils.image_dataset_from_directory(
    val_path,
    labels="inferred",
    label_mode="binary",
    class_names=["Closed_Eyes", "Open_Eyes"],
    color_mode="grayscale",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 672 files belonging to 2 classes.

# %%
eye_test_ds = tf.keras.utils.image_dataset_from_directory(
    test_path,
    labels="inferred",
    label_mode="binary",
    class_names=["Closed_Eyes", "Open_Eyes"],
    color_mode="grayscale",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 547 files belonging to 2 classes.

# %%
mouth_train_ds = tf.keras.utils.image_dataset_from_directory(
    train_path,
    labels="inferred",
    label_mode="binary",
    class_names=["No_yawn", "Yawn"],
    color_mode="rgb",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True
)
# Out:
# Found 4315 files belonging to 2 classes.

# %%
mouth_val_ds = tf.keras.utils.image_dataset_from_directory(
    val_path,
    labels="inferred",
    label_mode="binary",
    class_names=["No_yawn", "Yawn"],
    color_mode="rgb",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 882 files belonging to 2 classes.

# %%
mouth_test_ds = tf.keras.utils.image_dataset_from_directory(
    test_path,
    labels="inferred",
    label_mode="binary",
    class_names=["No_yawn", "Yawn"],
    color_mode="rgb",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 917 files belonging to 2 classes.

# %%
for images, labels in eye_train_ds.take(1):
    print("Eye Images shape:", images.shape)
    print("Eye Labels shape:", labels.shape)
# Out:
# Eye Images shape: (32, 64, 64, 1)
# Eye Labels shape: (32, 1)

# %%
for images, labels in mouth_train_ds.take(1):
    print("Mouth Images shape:", images.shape)
    print("Mouth Labels shape:", labels.shape)
# Out:
# Mouth Images shape: (32, 64, 64, 3)
# Mouth Labels shape: (32, 1)

# %%
plt.figure(figsize=(10, 10))

for images, labels in eye_train_ds.take(1):
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().squeeze(), cmap="gray")
        plt.title(eye_classes[int(labels[i].numpy()[0])])
        plt.axis("off")

plt.show()

# %%
plt.figure(figsize=(10, 10))

for images, labels in mouth_train_ds.take(1):
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(mouth_classes[int(labels[i].numpy()[0])])
        plt.axis("off")

plt.show()

# %%
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

eye_train_ds = eye_train_ds.map(
    lambda x, y: (preprocess_input(tf.cast(x, tf.float32)), y)
)

eye_val_ds = eye_val_ds.map(
    lambda x, y: (preprocess_input(tf.cast(x, tf.float32)), y)
)

eye_test_ds = eye_test_ds.map(
    lambda x, y: (preprocess_input(tf.cast(x, tf.float32)), y)
)

# %%
mouth_train_ds = mouth_train_ds.map(
    lambda x, y: (preprocess_input(tf.cast(x, tf.float32)), y)
)

mouth_val_ds = mouth_val_ds.map(
    lambda x, y: (preprocess_input(tf.cast(x, tf.float32)), y)
)

mouth_test_ds = mouth_test_ds.map(
    lambda x, y: (preprocess_input(tf.cast(x, tf.float32)), y)
)

# %%
for images, labels in eye_train_ds.take(1):
    print("Minimum pixel value:", tf.reduce_min(images).numpy())
    print("Maximum pixel value:", tf.reduce_max(images).numpy())
# Out:
# Minimum pixel value: -1.0
# Maximum pixel value: 1.0

# %%
for images, labels in mouth_train_ds.take(1):
    print("Mouth Minimum:", tf.reduce_min(images).numpy())
    print("Mouth Maximum:", tf.reduce_max(images).numpy())
# Out:
# Mouth Minimum: -1.0
# Mouth Maximum: 1.0

# %%
eye_data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1)
])

# %%
mouth_data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1)
])

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping

# %%
eye_base_model = MobileNetV2(
    weights="imagenet", include_top=False,input_shape=(64, 64, 3))

eye_base_model.trainable = False


eye_model = tf.keras.Sequential([ tf.keras.layers.Input(shape=(64, 64, 1)),

    tf.keras.layers.Lambda(
       lambda x: tf.image.grayscale_to_rgb(x)),

    eye_data_augmentation, eye_base_model,

    tf.keras.layers.GlobalAveragePooling2D(),

    tf.keras.layers.Dense( 128, activation="relu"),

    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense( 1, activation="sigmoid")])
# Out:
# /tmp/ipykernel_1709/1635073969.py:1: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   eye_base_model = MobileNetV2(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
eye_model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"])

# %%
mouth_base_model = MobileNetV2(
    weights="imagenet", include_top=False, input_shape=(64, 64, 3))

mouth_base_model.trainable = False


mouth_model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(64, 64, 3)),
    mouth_data_augmentation,mouth_base_model,

    tf.keras.layers.GlobalAveragePooling2D(),

    tf.keras.layers.Dense( 128, activation="relu"),

    tf.keras.layers.Dropout(0.5),
 tf.keras.layers.Dense( 1,activation="sigmoid" )])
# Out:
# /tmp/ipykernel_1709/2632153144.py:1: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   mouth_base_model = MobileNetV2(

# %%
for i, layer in enumerate(eye_model.layers):
    print(i, layer.name, type(layer).__name__)

# %% [markdown]
# **Training**

# %%
mouth_model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"])

# %%
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

mouth_history = mouth_model.fit(
    mouth_train_ds,
    validation_data=mouth_val_ds,
    epochs=20,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 34s 202ms/step - accuracy: 0.8908 - loss: 0.2729 - val_accuracy: 0.9501 - val_loss: 0.1383
# Epoch 2/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 24s 175ms/step - accuracy: 0.9384 - loss: 0.1778 - val_accuracy: 0.9365 - val_loss: 0.1767
# Epoch 3/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 23s 169ms/step - accuracy: 0.9428 - loss: 0.1606 - val_accuracy: 0.9512 - val_loss: 0.1261
# Epoch 4/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 25s 181ms/step - accuracy: 0.9486 - loss: 0.1501 - val_accuracy: 0.9399 - val_loss: 0.1635
# Epoch 5/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 22s 163ms/step - accuracy: 0.9520 - loss: 0.1345 - val_accuracy: 0.9558 - val_loss: 0.1154
# Epoch 6/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 42s 175ms/step - accuracy: 0.9541 - loss: 0.1322 - val_accuracy: 0.9546 - val_loss: 0.1182
# Epoch 7/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9520 - loss: 0.1307 - val_accuracy: 0.9501 - val_loss: 0.1404
# Epoch 8/20
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 25s 187ms/step - accuracy: 0.9592 - loss: 0.1247 - val_accuracy: 0.9240 - val_loss: 0.1814

# %%
mouth_model.summary()

# %%
eye_history = eye_model.fit(
    eye_train_ds,
    validation_data=eye_val_ds,
    epochs=20,
    callbacks=[early_stopping]
)

# %%
eye_model.summary()

# %%
mouth_base_model.trainable = True

for layer in mouth_base_model.layers[:-30]:
    layer.trainable = False

# %%
eye_base_model.trainable = True

for layer in eye_base_model.layers[:-30]:
    layer.trainable = False

# %%
from tensorflow.keras.optimizers import Adam

mouth_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
print("Number of layers in the base model:", len(mouth_base_model.layers))

# %%
eye_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
print("Number of layers in the base model:", len(eye_base_model.layers))

# %%
mouth_fine_tune_history = mouth_model.fit(
    mouth_train_ds,
    validation_data=mouth_val_ds,
    epochs=15,
    callbacks=[early_stopping]
)

# %%
eye_fine_tune_history = eye_model.fit(
    eye_train_ds,
    validation_data=eye_val_ds,
    epochs=15,
    callbacks=[early_stopping]
)

# %%
y_true = []
y_pred = []

for images, labels in mouth_test_ds:
    predictions = mouth_model.predict(images, verbose=0)

    y_true.extend(labels.numpy().flatten())
    y_pred.extend((predictions >= 0.5).astype(int).flatten())

print(classification_report(
    y_true,
    y_pred,
    target_names=["No_yawn", "Yawn"]
))

# %%
y_true = []
y_pred = []

for images, labels in eye_test_ds:
    predictions = eye_model.predict(images, verbose=0)

    y_true.extend(labels.numpy().flatten())
    y_pred.extend((predictions >= 0.5).astype(int).flatten())

print(classification_report(
    y_true,
    y_pred,
    target_names=["Closed_Eyes", "Open_Eyes"]
))

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(5, 4))
plt.imshow(cm)
plt.title("Mouth Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.xticks([0, 1], ["No Yawn", "Yawn"])
plt.yticks([0, 1], ["No Yawn", "Yawn"])

for i in range(2):
    for j in range(2):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.show()

# %%
test_loss, test_accuracy = mouth_model.evaluate(mouth_test_ds)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Test Accuracy (%):", test_accuracy * 100)

# %%
test_loss, test_accuracy = eye_model.evaluate(eye_test_ds)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
print("Test Accuracy (%):", test_accuracy * 100)

# %%
eye_model.save("/content/eye_model.keras")
mouth_model.save("/content/mouth_model.keras")

print("Models saved successfully.")

# %% [markdown]
# # Face & Feature Detection

# %%
import os

print("Eye model:", os.path.exists("/content/eye_model.keras"))
print("Mouth model:", os.path.exists("/content/mouth_model.keras"))

# %%
# !wget -q -O /content/face_detection_yunet_2023mar.onnx \
https://github.com/opencv/opencv_zoo/raw/main/models/face_detection_yunet/face_detection_yunet_2023mar.onnx

import os
print("YuNet downloaded:",os.path.exists("/content/face_detection_yunet_2023mar.onnx"))

# %%
import cv2
import numpy as np

print("Initializing Face Detector...")

face_detector = cv2.FaceDetectorYN.create(
    "/content/face_detection_yunet_2023mar.onnx",
    "",
    (320, 320),
    0.6,
    0.3,
    5000)

print("Face detector ready")

# %%
def detect_face(frame):

    height, width = frame.shape[:2]
    face_detector.setInputSize((width, height))

    _, faces = face_detector.detect(frame)

    if faces is None or len(faces) == 0:
        return None

    largest_face = max(
        faces,
        key=lambda face: face[2] * face[3])

    return largest_face

# %%
def extract_eye_mouth_regions(frame, face):

    x, y, w, h = face[:4].astype(int)

    # YuNet landmark positions
    right_eye = face[4:6]
    left_eye = face[6:8]
    nose = face[8:10]
    right_mouth = face[10:12]
    left_mouth = face[12:14]

    # Eye region
    eye_x1 = int(min(right_eye[0], left_eye[0]) - 0.35 * w)
    eye_x2 = int(max(right_eye[0], left_eye[0]) + 0.35 * w)

    eye_y1 = int(min(right_eye[1], left_eye[1]) - 0.15 * h)
    eye_y2 = int(max(right_eye[1], left_eye[1]) + 0.25 * h)

    # Mouth region
    mouth_x1 = int(min(right_mouth[0], left_mouth[0]) - 0.20 * w)
    mouth_x2 = int(max(right_mouth[0], left_mouth[0]) + 0.20 * w)

    mouth_y1 = int(min(right_mouth[1], left_mouth[1]) - 0.20 * h)
    mouth_y2 = int(max(right_mouth[1], left_mouth[1]) + 0.35 * h)

    # Keep coordinates inside the frame
    eye_x1 = max(0, eye_x1)
    eye_y1 = max(0, eye_y1)
    eye_x2 = min(frame.shape[1], eye_x2)
    eye_y2 = min(frame.shape[0], eye_y2)

    mouth_x1 = max(0, mouth_x1)
    mouth_y1 = max(0, mouth_y1)
    mouth_x2 = min(frame.shape[1], mouth_x2)
    mouth_y2 = min(frame.shape[0], mouth_y2)

    eye_crop = frame[eye_y1:eye_y2, eye_x1:eye_x2]
    mouth_crop = frame[mouth_y1:mouth_y2, mouth_x1:mouth_x2]

    return (
        eye_crop,
        mouth_crop,
        (eye_x1, eye_y1, eye_x2, eye_y2),
        (mouth_x1, mouth_y1, mouth_x2, mouth_y2))

# %%
print("Face & feature detection functions are ready")

# %%
import tensorflow as tf

print("Loading models...")

eye_model = tf.keras.models.load_model(
    "/content/eye_model.keras",
    safe_mode=False
)

print("Eye model loaded")

mouth_model = tf.keras.models.load_model(
    "/content/mouth_model.keras",
    safe_mode=False
)

print("Mouth model loaded")

# %%
import tensorflow as tf

for layer in eye_model.layers:
    if isinstance(layer, tf.keras.layers.Lambda):
        layer.function.__globals__["tf"] = tf
        print("Eye Lambda fixed")

# %%
import tensorflow as tf
import numpy as np

for layer in mouth_model.layers:
    if isinstance(layer, tf.keras.layers.Lambda):
        layer.function.__globals__["tf"] = tf
        print("Mouth Lambda fixed")

# %%
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

def predict_eye(eye_crop):

    eye_crop = cv2.resize(eye_crop, (64, 64))

    if len(eye_crop.shape) == 3:
        eye_crop = cv2.cvtColor(
            eye_crop,
            cv2.COLOR_BGR2GRAY
        )

    eye_crop = np.expand_dims(eye_crop, axis=-1)

    eye_crop = eye_crop.astype(np.float32)

    eye_crop = preprocess_input(eye_crop)


    eye_crop = np.expand_dims(eye_crop, axis=0)

    prediction = eye_model.predict(
        eye_crop,
        verbose=0
    )[0][0]

    if prediction < 0.5:
        state = "Closed"
    else:
        state = "Open"

    return state, float(prediction)

# %%
def predict_mouth(mouth_crop):

    mouth_crop = cv2.resize(mouth_crop, (64, 64))

    if len(mouth_crop.shape) == 2:
        mouth_crop = cv2.cvtColor(
            mouth_crop,
            cv2.COLOR_GRAY2RGB
        )

    mouth_crop = mouth_crop.astype(np.float32)

    mouth_crop = preprocess_input(mouth_crop)

    mouth_crop = np.expand_dims(mouth_crop, axis=0)

    prediction = mouth_model.predict(
        mouth_crop,
        verbose=0
    )[0][0]

    if prediction < 0.5:
        state = "No Yawn"
    else:
        state = "Yawn"

    return state, float(prediction)

# %%
from google.colab import files
import cv2
import numpy as np

uploaded = files.upload()

image_path = next(iter(uploaded))

image = cv2.imread(image_path)

print(image.shape)

# %%
face = detect_face(image)

if face is None:

    print("No face detected.")

else:

    result = extract_eye_mouth_regions(
        image,
        face
    )

    eye_crop = result[0]
    mouth_crop = result[1]

    eye_state, eye_score = predict_eye(
        eye_crop
    )

    mouth_state, mouth_score = predict_mouth(
        mouth_crop
    )

    print("Eye:", eye_state)
    print("Mouth:", mouth_state)

# %%
if eye_state == "Closed" and mouth_state == "Yawn":
    final_result = "DROWSY"

elif eye_state == "Closed":
    final_result = "POSSIBLE DROWSINESS"

elif mouth_state == "Yawn":
    final_result = "POSSIBLE DROWSINESS"

else:
    final_result = "ALERT"

print("Eye Status:", eye_state)
print("Mouth Status:", mouth_state)
print("Final Result:", final_result)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(cv2.cvtColor(eye_crop, cv2.COLOR_BGR2RGB))
plt.title(f"Eye: {eye_state}")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(mouth_crop, cv2.COLOR_BGR2RGB))
plt.title(f"Mouth: {mouth_state}")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import os

for root, dirs, files in os.walk('/content'):
    for file in files:
        if file.endswith('.onnx'):
            print(os.path.join(root, file))

# %%
import os

BLYNK_TOKEN = os.getenv("BLYNK_TOKEN")

# %%
from google.colab import files

files.download("/content/face_detection_yunet_2023mar.onnx")

# %%
dummy_input = tf.random.uniform((1, 64, 64, 3))

test_prediction = eye_model_deploy.predict(dummy_input)

print("Prediction:", test_prediction)

# %%
# Get the existing layers from the trained model
eye_augmentation = eye_model.layers[1]
eye_base_model = eye_model.layers[2]
eye_gap = eye_model.layers[3]
eye_dense = eye_model.layers[4]
eye_dropout = eye_model.layers[5]
eye_output = eye_model.layers[6]

# New input: RGB instead of grayscale
inputs = tf.keras.Input(shape=(64, 64, 3))

x = eye_augmentation(inputs)
x = eye_base_model(x)
x = eye_gap(x)
x = eye_dense(x)
x = eye_dropout(x)
outputs = eye_output(x)

# Create deployment model
eye_model_deploy = tf.keras.Model(
    inputs=inputs,
    outputs=outputs
)

eye_model_deploy.summary()

# %%
eye_model_deploy.save("eye_model_deploy.keras")

# %%
import os

print(os.path.exists("eye_model_deploy.keras"))

# %%
import os

print("Eye model:", os.path.exists("/content/eye_model.keras"))
print("Mouth model:", os.path.exists("/content/mouth_model.keras"))
print("Eye deploy model:", os.path.exists("/content/eye_model_deploy.keras"))
print("YuNet:", os.path.exists("/content/face_detection_yunet_2023mar.onnx"))
